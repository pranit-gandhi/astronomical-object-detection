# %%
import torch
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import os
import torch.nn as nn
import torch.nn.functional as F

# %%
DATA_PATH = "../data/astro_dataset_maxia/astro_dataset_maxia"

# %%
image_sz = 128 
batch_sz = 32

# %%
from torchvision import transforms

# Preprocessing: Image Resize to be same size, for each image
# Preprocessing: Randomly Rotating Images about y-axis
# Preprocessing: Normalizing pixel values

train_transform = transforms.Compose([
    transforms.Resize((image_sz, image_sz)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(), 
    transforms.Normalize(mean=[0.5, 0.5, 0.5],
                         std=[0.5, 0.5, 0.5]),
])

eval_transform = transforms.Compose([
    transforms.Resize((image_sz, image_sz)),
    transforms.ToTensor(), 
    transforms.Normalize(mean=[0.5, 0.5, 0.5],
                         std=[0.5, 0.5, 0.5]),
])

# %%
train_data = datasets.ImageFolder(os.path.join(DATA_PATH, "training"), transform=train_transform)
test_data  = datasets.ImageFolder(os.path.join(DATA_PATH, "test"), transform=eval_transform)
val_data  = datasets.ImageFolder(os.path.join(DATA_PATH, "validation"), transform=eval_transform)

print("Classes:", train_data.classes)
print("Number of Classes:", len(train_data.classes))
print("Training Samples:", len(train_data))
print("Val Samples:", len(val_data))
print("Test Samples:", len(test_data))
print("Total Samples:", len(train_data)+len(val_data)+len(test_data))
# Out:
# Classes: ['asteroid', 'black_hole', 'earth', 'galaxy', 'jupiter', 'mars', 'mercury', 'neptune', 'pluto', 'saturn', 'uranus', 'venus']
# Number of Classes: 12
# Training Samples: 2416
# Val Samples: 658
# Test Samples: 345
# Total Samples: 3419

# %%
class CNN(nn.Module):
    def __init__(self, num_classes, img_sz):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 64, padding=1, kernel_size=3)
        self.conv2 = nn.Conv2d(64, 128, padding=1, kernel_size=3)
        self.conv3 = nn.Conv2d(128, 256, padding=1, kernel_size=3)
        self.pool = nn.MaxPool2d(2,2)

        total_nodes = 256*int(img_sz/8)**2

        self.layer1 = nn.Linear(total_nodes, 256)
        self.dropout = nn.Dropout(0.35)

        self.layer2 = nn.Linear(256, num_classes)

    
    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.pool(x)

        x = self.conv2(x)
        x = F.relu(x)
        x = self.pool(x)

        x = self.conv3(x)
        x = F.relu(x)
        x = self.pool(x)

        x = x.view(x.size(0), -1)

        x = self.layer1(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.layer2(x)

        return x

# %%
class CNN_Ultra(nn.Module):
    def __init__(self, num_classes, img_sz):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 64, padding=1, kernel_size=3)
        self.conv2 = nn.Conv2d(64, 128, padding=1, kernel_size=3)
        self.conv3 = nn.Conv2d(128, 256, padding=1, kernel_size=3)
        self.conv4 = nn.Conv2d(256, 512,  padding=1, kernel_size=3)
        self.pool = nn.MaxPool2d(2,2)

        total_nodes = 512*int(img_sz/8)**2

        self.layer1 = nn.Linear(total_nodes, 512)
        self.dropout = nn.Dropout(0.3)

        self.layer2 = nn.Linear(512, num_classes)


    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.pool(x)

        x = self.conv2(x)
        x = F.relu(x)
        x = self.pool(x)

        x = self.conv3(x)
        x = F.relu(x)
        x = self.pool(x)

        x = self.conv4(x)
        x = F.relu(x)

        x = x.view(x.size(0), -1)

        x = self.layer1(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.layer2(x)

        return x

# %%
class CNN_Turbo(nn.Module):
    def __init__(self, num_classes, img_sz):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 64, padding=1, kernel_size=3)
        self.pool = nn.MaxPool2d(2,2)

        total_nodes = 64*int(img_sz/2)**2

        self.layer1 = nn.Linear(total_nodes, 64)
        self.dropout = nn.Dropout(0.15)

        self.layer2 = nn.Linear(64, num_classes)


    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.pool(x)

        x = x.view(x.size(0), -1)

        x = self.layer1(x)
        x = F.relu(x)
        
        x = self.dropout(x)

        x = self.layer2(x)

        return x

# %%
class CNN_Lite(nn.Module):
    def __init__(self, num_classes, img_sz):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 64, padding=1, kernel_size=3)
        self.conv2 = nn.Conv2d(64, 128, padding=1, kernel_size=3)
        self.pool = nn.MaxPool2d(2,2)

        total_nodes = 128*int(img_sz/4)**2

        self.layer1 = nn.Linear(total_nodes, 128)
        self.dropout = nn.Dropout(0.2)

        self.layer2 = nn.Linear(128, num_classes)

    
    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.pool(x)

        x = self.conv2(x)
        x = F.relu(x)
        x = self.pool(x)

        x = x.view(x.size(0), -1)

        x = self.layer1(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.layer2(x)

        return x

# %%
train_loader = DataLoader(train_data, batch_size=batch_sz, shuffle=True)
val_loader   = DataLoader(val_data,   batch_size=batch_sz, shuffle=False)
test_loader  = DataLoader(test_data,  batch_size=batch_sz, shuffle=False)

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    model = CNN(len(train_data.classes), image_sz).to(device)

# %%
import torch.optim as optim

def cnn_trainer(CNNmodel, epochs, lamb=0):
    model = CNNmodel(num_classes=len(train_data.classes), img_sz=image_sz).to(device)
    print(device)
    
    histmap = {"train_loss": [],
               "train_accuracy": [],  
               "val_loss": [], 
               "val_accuracy": []
    }

    adam = optim.Adam(model.parameters(), lr=1e-3, weight_decay=lamb)
    objective = nn.CrossEntropyLoss()

    for epoch in range(1, epochs+1):
        model.train()
        correct = 0
        total = 0
        cur_loss = 0.0


        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            adam.zero_grad()
            outputs = model(images)
            loss = objective(outputs, labels)
            loss.backward()
            adam.step()

            cur_loss += loss.item() * labels.size(0)
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

        train_loss = cur_loss/total
        train_accuracy = correct/total

        model.eval()
        val_correct = 0
        val_total = 0
        val_loss_sum = 0


        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = objective(outputs, labels)
                val_loss_sum += loss.item() * labels.size(0)

                _, preds = torch.max(outputs, 1)
                val_total += labels.size(0)
                val_correct += (preds == labels).sum().item()

        val_loss = val_loss_sum / val_total
        val_accuracy = val_correct / val_total

        histmap["train_loss"].append(train_loss)
        histmap["train_accuracy"].append(train_accuracy)

        histmap["val_loss"].append(val_loss)
        histmap["val_accuracy"].append(val_accuracy)

        print(f"lambda: {lamb} and epoch: {epoch} of {epochs}, train accuracy: {train_accuracy} and val accuracy: {val_accuracy}")

    return model, histmap

# %%
lamb_exp = 0.01
model_test, hist_test = cnn_trainer(CNN, 3, lamb_exp)
# Out:
# cuda
# lambda: 0.01 and epoch: 1 of 3, train accuracy: 0.4913079470198676 and val accuracy: 0.621580547112462
# lambda: 0.01 and epoch: 2 of 3, train accuracy: 0.6870860927152318 and val accuracy: 0.7203647416413373
# lambda: 0.01 and epoch: 3 of 3, train accuracy: 0.7189569536423841 and val accuracy: 0.7583586626139818

# %%
lambs = [0, 0.01, 0.001, 0.005, 0.0001, 0.0005]

# %%
res = {}

for lamb in lambs:
    filename = "CNN_lambda-"+str(lamb)+".pth"
    model, histmap = cnn_trainer(CNN, 14, lamb)
    res[lamb] = histmap

    torch.save(model.state_dict(), filename)
    print("Saved:", filename)
# Out:
# cuda
# lambda: 0 and epoch: 1 of 14, train accuracy: 0.4859271523178808 and val accuracy: 0.7629179331306991
# lambda: 0 and epoch: 2 of 14, train accuracy: 0.7379966887417219 and val accuracy: 0.8343465045592705
# lambda: 0 and epoch: 3 of 14, train accuracy: 0.8133278145695364 and val accuracy: 0.851063829787234
# lambda: 0 and epoch: 4 of 14, train accuracy: 0.847682119205298 and val accuracy: 0.8617021276595744
# lambda: 0 and epoch: 5 of 14, train accuracy: 0.8733443708609272 and val accuracy: 0.8829787234042553
# lambda: 0 and epoch: 6 of 14, train accuracy: 0.8973509933774835 and val accuracy: 0.8844984802431611
# lambda: 0 and epoch: 7 of 14, train accuracy: 0.9126655629139073 and val accuracy: 0.8936170212765957
# lambda: 0 and epoch: 8 of 14, train accuracy: 0.9246688741721855 and val accuracy: 0.9027355623100304
# lambda: 0 and epoch: 9 of 14, train accuracy: 0.9387417218543046 and val accuracy: 0.9027355623100304
# lambda: 0 and epoch: 10 of 14, train accuracy: 0.9391556291390728 and val accuracy: 0.9103343465045592
# lambda: 0 and epoch: 11 of 14, train accuracy: 0.9449503311258278 and val accuracy: 0.9088145896656535
# lambda: 0 and epoch: 12 of 14, train accuracy: 0.9577814569536424 and val accuracy: 0.9316109422492401
# lambda: 0 and epoch: 13 of 14, train accuracy: 0.9598509933774835 and val accuracy: 0.9270516717325228
# lambda: 0 and epoch: 14 of 14, train accuracy: 0.9664735099337748 and val accuracy: 0.9194528875379939
# Saved: CNN_lambda-0.pth
# cuda
# lambda: 0.01 and epoch: 1 of 14, train accuracy: 0.5128311258278145 and val accuracy: 0.7021276595744681
# lambda: 0.01 and epoch: 2 of 14, train accuracy: 0.6932947019867549 and val accuracy: 0.7963525835866262
# lambda: 0.01 and epoch: 3 of 14, train accuracy: 0.769453642384106 and val accuracy: 0.8085106382978723
# lambda: 0.01 and epoch: 4 of 14, train accuracy: 0.7992549668874173 and val accuracy: 0.8282674772036475
# lambda: 0.01 and epoch: 5 of 14, train accuracy: 0.8050496688741722 and val accuracy: 0.8237082066869301
# lambda: 0.01 and epoch: 6 of 14, train accuracy: 0.8245033112582781 and val accuracy: 0.8708206686930091
# lambda: 0.01 and epoch: 7 of 14, train accuracy: 0.8261589403973509 and val accuracy: 0.8419452887537994
# lambda: 0.01 and epoch: 8 of 14, train accuracy: 0.8389900662251656 and val accuracy: 0.8708206686930091
# lambda: 0.01 and epoch: 9 of 14, train accuracy: 0.8427152317880795 and val accuracy: 0.8844984802431611
# lambda: 0.01 and epoch: 10 of 14, train accuracy: 0.8563741721854304 and val accuracy: 0.8753799392097265
# lambda: 0.01 and epoch: 11 of 14, train accuracy: 0.8505794701986755 and val accuracy: 0.8723404255319149
# lambda: 0.01 and epoch: 12 of 14, train accuracy: 0.8485099337748344 and val accuracy: 0.8768996960486323
# lambda: 0.01 and epoch: 13 of 14, train accuracy: 0.8638245033112583 and val accuracy: 0.8404255319148937
# lambda: 0.01 and epoch: 14 of 14, train accuracy: 0.8613410596026491 and val accuracy: 0.8768996960486323
# Saved: CNN_lambda-0.01.pth
# cuda
# lambda: 0.001 and epoch: 1 of 14, train accuracy: 0.48841059602649006 and val accuracy: 0.6641337386018237
# lambda: 0.001 and epoch: 2 of 14, train accuracy: 0.7388245033112583 and val accuracy: 0.8054711246200608
# lambda: 0.001 and epoch: 3 of 14, train accuracy: 0.8137417218543046 and val accuracy: 0.8389057750759878
# lambda: 0.001 and epoch: 4 of 14, train accuracy: 0.8340231788079471 and val accuracy: 0.8449848024316109
# lambda: 0.001 and epoch: 5 of 14, train accuracy: 0.8567880794701986 and val accuracy: 0.8829787234042553
# lambda: 0.001 and epoch: 6 of 14, train accuracy: 0.8911423841059603 and val accuracy: 0.9103343465045592
# lambda: 0.001 and epoch: 7 of 14, train accuracy: 0.9048013245033113 and val accuracy: 0.8936170212765957
# lambda: 0.001 and epoch: 8 of 14, train accuracy: 0.9068708609271523 and val accuracy: 0.9057750759878419
# lambda: 0.001 and epoch: 9 of 14, train accuracy: 0.9184602649006622 and val accuracy: 0.9194528875379939
# lambda: 0.001 and epoch: 10 of 14, train accuracy: 0.9346026490066225 and val accuracy: 0.9012158054711246
# lambda: 0.001 and epoch: 11 of 14, train accuracy: 0.9333609271523179 and val accuracy: 0.8996960486322189
# lambda: 0.001 and epoch: 12 of 14, train accuracy: 0.9387417218543046 and val accuracy: 0.9209726443768997
# lambda: 0.001 and epoch: 13 of 14, train accuracy: 0.9375 and val accuracy: 0.9240121580547113
# lambda: 0.001 and epoch: 14 of 14, train accuracy: 0.9577814569536424 and val accuracy: 0.9346504559270516
# Saved: CNN_lambda-0.001.pth
# cuda
# lambda: 0.005 and epoch: 1 of 14, train accuracy: 0.4759933774834437 and val accuracy: 0.7249240121580547
# lambda: 0.005 and epoch: 2 of 14, train accuracy: 0.7388245033112583 and val accuracy: 0.7948328267477204
# lambda: 0.005 and epoch: 3 of 14, train accuracy: 0.7566225165562914 and val accuracy: 0.8252279635258358
# lambda: 0.005 and epoch: 4 of 14, train accuracy: 0.8112582781456954 and val accuracy: 0.8267477203647416
# lambda: 0.005 and epoch: 5 of 14, train accuracy: 0.8493377483443708 and val accuracy: 0.8617021276595744
# lambda: 0.005 and epoch: 6 of 14, train accuracy: 0.8340231788079471 and val accuracy: 0.8632218844984803
# lambda: 0.005 and epoch: 7 of 14, train accuracy: 0.8509933774834437 and val accuracy: 0.8677811550151976
# lambda: 0.005 and epoch: 8 of 14, train accuracy: 0.8547185430463576 and val accuracy: 0.8799392097264438
# lambda: 0.005 and epoch: 9 of 14, train accuracy: 0.8820364238410596 and val accuracy: 0.8677811550151976
# lambda: 0.005 and epoch: 10 of 14, train accuracy: 0.8774834437086093 and val accuracy: 0.878419452887538
# lambda: 0.005 and epoch: 11 of 14, train accuracy: 0.8857615894039735 and val accuracy: 0.8829787234042553
# lambda: 0.005 and epoch: 12 of 14, train accuracy: 0.8870033112582781 and val accuracy: 0.8708206686930091
# lambda: 0.005 and epoch: 13 of 14, train accuracy: 0.8853476821192053 and val accuracy: 0.8708206686930091
# lambda: 0.005 and epoch: 14 of 14, train accuracy: 0.8878311258278145 and val accuracy: 0.8860182370820668
# Saved: CNN_lambda-0.005.pth
# cuda
# lambda: 0.0001 and epoch: 1 of 14, train accuracy: 0.5120033112582781 and val accuracy: 0.7066869300911854
# lambda: 0.0001 and epoch: 2 of 14, train accuracy: 0.7400662251655629 and val accuracy: 0.8009118541033434
# lambda: 0.0001 and epoch: 3 of 14, train accuracy: 0.8120860927152318 and val accuracy: 0.8328267477203647
# lambda: 0.0001 and epoch: 4 of 14, train accuracy: 0.8551324503311258 and val accuracy: 0.8829787234042553
# lambda: 0.0001 and epoch: 5 of 14, train accuracy: 0.8824503311258278 and val accuracy: 0.8662613981762918
# lambda: 0.0001 and epoch: 6 of 14, train accuracy: 0.890728476821192 and val accuracy: 0.9027355623100304
# lambda: 0.0001 and epoch: 7 of 14, train accuracy: 0.9130794701986755 and val accuracy: 0.9103343465045592
# lambda: 0.0001 and epoch: 8 of 14, train accuracy: 0.9333609271523179 and val accuracy: 0.9088145896656535
# lambda: 0.0001 and epoch: 9 of 14, train accuracy: 0.9391556291390728 and val accuracy: 0.9164133738601824
# lambda: 0.0001 and epoch: 10 of 14, train accuracy: 0.9528145695364238 and val accuracy: 0.9300911854103343
# lambda: 0.0001 and epoch: 11 of 14, train accuracy: 0.9428807947019867 and val accuracy: 0.9285714285714286
# lambda: 0.0001 and epoch: 12 of 14, train accuracy: 0.9627483443708609 and val accuracy: 0.9209726443768997
# lambda: 0.0001 and epoch: 13 of 14, train accuracy: 0.9515728476821192 and val accuracy: 0.9346504559270516
# lambda: 0.0001 and epoch: 14 of 14, train accuracy: 0.9668874172185431 and val accuracy: 0.9331306990881459
# Saved: CNN_lambda-0.0001.pth
# cuda
# lambda: 0.0005 and epoch: 1 of 14, train accuracy: 0.46647350993377484 and val accuracy: 0.7249240121580547
# lambda: 0.0005 and epoch: 2 of 14, train accuracy: 0.7491721854304636 and val accuracy: 0.8039513677811551
# lambda: 0.0005 and epoch: 3 of 14, train accuracy: 0.8178807947019867 and val accuracy: 0.8145896656534954
# lambda: 0.0005 and epoch: 4 of 14, train accuracy: 0.8456125827814569 and val accuracy: 0.8753799392097265
# lambda: 0.0005 and epoch: 5 of 14, train accuracy: 0.8729304635761589 and val accuracy: 0.8844984802431611
# lambda: 0.0005 and epoch: 6 of 14, train accuracy: 0.8882450331125827 and val accuracy: 0.8996960486322189
# lambda: 0.0005 and epoch: 7 of 14, train accuracy: 0.902317880794702 and val accuracy: 0.9042553191489362
# lambda: 0.0005 and epoch: 8 of 14, train accuracy: 0.9085264900662252 and val accuracy: 0.8936170212765957
# lambda: 0.0005 and epoch: 9 of 14, train accuracy: 0.9147350993377483 and val accuracy: 0.9027355623100304
# lambda: 0.0005 and epoch: 10 of 14, train accuracy: 0.9337748344370861 and val accuracy: 0.9042553191489362
# lambda: 0.0005 and epoch: 11 of 14, train accuracy: 0.9333609271523179 and val accuracy: 0.9027355623100304
# lambda: 0.0005 and epoch: 12 of 14, train accuracy: 0.9428807947019867 and val accuracy: 0.9042553191489362
# lambda: 0.0005 and epoch: 13 of 14, train accuracy: 0.9441225165562914 and val accuracy: 0.925531914893617
# lambda: 0.0005 and epoch: 14 of 14, train accuracy: 0.9457781456953642 and val accuracy: 0.9194528875379939
# Saved: CNN_lambda-0.0005.pth

# %%
res
# Out:
# {0: {'train_loss': [1.5898193322270122,
#    0.792324359843273,
#    0.574714989259543,
#    0.4596526308959683,
#    0.37858685130709846,
#    0.31432364737948043,
#    0.27391967680675305,
#    0.23979092961707651,
#    0.1787006850570243,
#    0.18992350428112295,
#    0.14435225552478373,
#    0.12347792393053013,
#    0.1229284115826452,
#    0.09890862847894233],
#   'train_accuracy': [0.4859271523178808,
#    0.7379966887417219,
#    0.8133278145695364,
#    0.847682119205298,
#    0.8733443708609272,
#    0.8973509933774835,
#    0.9126655629139073,
#    0.9246688741721855,
#    0.9387417218543046,
#    0.9391556291390728,
#    0.9449503311258278,
#    0.9577814569536424,
#    0.9598509933774835,
#    0.9664735099337748],
#   'val_loss': [0.8394283245580899,
#    0.5796191444150582,
#    0.47783586797856453,
#    0.4487835445574352,
#    0.41606758768163554,
#    0.4070993214321965,
#    0.30976974455169815,
#    0.31975000576439205,
#    0.39423588729013426,
#    0.34671219677894694,
#    0.3770630520397456,
#    0.2777733909541449,
#    0.29939473961862073,
#    0.35807985211312054],
#   'val_accuracy': [0.7629179331306991,
#    0.8343465045592705,
#    0.851063829787234,
#    0.8617021276595744,
#    0.8829787234042553,
#    0.8844984802431611,
#    0.8936170212765957,
#    0.9027355623100304,
#    0.9027355623100304,
#    0.9103343465045592,
#    0.9088145896656535,
#    0.9316109422492401,
#    0.9270516717325228,
#    0.9194528875379939]},
#  0.01: {'train_loss': [1.4600521926058838,
#    0.9385290597843019,
#    0.718666352973079,
#    0.6462997375734595,
#    0.5835315735134857,
#    0.5266850803861555,
#    0.5316304627633253,
#    0.48382200942134224,
#    0.4692371915902523,
#    0.4719200223092212,
#    0.4533351414053645,
#    0.4568591576735705,
#    0.42733994501315997,
#    0.4225632238467008],
#   'train_accuracy': [0.5128311258278145,
#    0.6932947019867549,
#    0.769453642384106,
#    0.7992549668874173,
#    0.8050496688741722,
#    0.8245033112582781,
#    0.8261589403973509,
#    0.8389900662251656,
#    0.8427152317880795,
#    0.8563741721854304,
#    0.8505794701986755,
#    0.8485099337748344,
#    0.8638245033112583,
#    0.8613410596026491],
#   'val_loss': [0.9167149335961211,
#    0.6644082312163611,
#    0.6442160369052713,
#    0.5355612346251413,
#    0.5080526838118725,
#    0.4402029550093648,
#    0.4925284573191205,
#    0.41427511514637244,
#    0.3920339069620771,
#    0.42457415068403204,
#    0.43589303500123755,
#    0.3883592141367563,
#    0.4678254509344697,
#    0.4211664872419508],
#   'val_accuracy': [0.7021276595744681,
#    0.7963525835866262,
#    0.8085106382978723,
#    0.8282674772036475,
#    0.8237082066869301,
#    0.8708206686930091,
#    0.8419452887537994,
#    0.8708206686930091,
#    0.8844984802431611,
#    0.8753799392097265,
#    0.8723404255319149,
#    0.8768996960486323,
#    0.8404255319148937,
#    0.8768996960486323]},
#  0.001: {'train_loss': [1.526658936052133,
#    0.7827711176398574,
#    0.5839420387287013,
#    0.47465144166883255,
#    0.41292311083402067,
#    0.34934079883903857,
#    0.2890239692484306,
#    0.2855962410766557,
#    0.22921739612391454,
#    0.2105289561957713,
#    0.20068781067993466,
#    0.1874048752796571,
#    0.17412714961151413,
#    0.14212144842210983],
#   'train_accuracy': [0.48841059602649006,
#    0.7388245033112583,
#    0.8137417218543046,
#    0.8340231788079471,
#    0.8567880794701986,
#    0.8911423841059603,
#    0.9048013245033113,
#    0.9068708609271523,
#    0.9184602649006622,
#    0.9346026490066225,
#    0.9333609271523179,
#    0.9387417218543046,
#    0.9375,
#    0.9577814569536424],
#   'val_loss': [0.9545453266215179,
#    0.5863409313659175,
#    0.5022384671318857,
#    0.4929568887940158,
#    0.3957057449213685,
#    0.35094344389474863,
#    0.33921400928660367,
#    0.3143468376101875,
#    0.2853988695781435,
#    0.3218405794403247,
#    0.32683598612488945,
#    0.2835322636544795,
#    0.310271176840759,
#    0.29444131780204175],
#   'val_accuracy': [0.6641337386018237,
#    0.8054711246200608,
#    0.8389057750759878,
#    0.8449848024316109,
#    0.8829787234042553,
#    0.9103343465045592,
#    0.8936170212765957,
#    0.9057750759878419,
#    0.9194528875379939,
#    0.9012158054711246,
#    0.8996960486322189,
#    0.9209726443768997,
#    0.9240121580547113,
#    0.9346504559270516]},
#  0.005: {'train_loss': [1.5717241093022933,
#    0.8183644413948059,
#    0.6963459699359161,
#    0.5681613202126611,
#    0.4497100612185649,
#    0.4778163582086563,
#    0.4673516201657175,
#    0.4303319160117219,
#    0.36257083654798417,
#    0.35898832078801085,
#    0.3460966082203467,
#    0.3349400962030651,
#    0.33340687793216955,
#    0.32740017031596985],
#   'train_accuracy': [0.4759933774834437,
#    0.7388245033112583,
#    0.7566225165562914,
#    0.8112582781456954,
#    0.8493377483443708,
#    0.8340231788079471,
#    0.8509933774834437,
#    0.8547185430463576,
#    0.8820364238410596,
#    0.8774834437086093,
#    0.8857615894039735,
#    0.8870033112582781,
#    0.8853476821192053,
#    0.8878311258278145],
#   'val_loss': [0.880944298212289,
#    0.6658081542757145,
#    0.5532691423925585,
#    0.5382864833738666,
#    0.430796317841099,
#    0.48717950076136546,
#    0.455891270591031,
#    0.40048543520917196,
#    0.41457031902893926,
#    0.39935039102147957,
#    0.39933351702750364,
#    0.4021894744637006,
#    0.41737856138157897,
#    0.39601179721303803],
#   'val_accuracy': [0.7249240121580547,
#    0.7948328267477204,
#    0.8252279635258358,
#    0.8267477203647416,
#    0.8617021276595744,
#    0.8632218844984803,
#    0.8677811550151976,
#    0.8799392097264438,
#    0.8677811550151976,
#    0.878419452887538,
#    0.8829787234042553,
#    0.8708206686930091,
#    0.8708206686930091,
#    0.8860182370820668]},
#  0.0001: {'train_loss': [1.51889649329596,
#    0.7932237927487354,
#    0.5749734910513391,
#    0.4435858107757884,
#    0.37879828674509036,
#    0.31517950608240847,
#    0.2558534186308747,
#    0.2064264373274039,
#    0.19819418300522973,
#    0.15877635073878907,
#    0.1788325242278789,
#    0.13906149250387356,
#    0.14982447565983462,
#    0.09288302219367975],
#   'train_accuracy': [0.5120033112582781,
#    0.7400662251655629,
#    0.8120860927152318,
#    0.8551324503311258,
#    0.8824503311258278,
#    0.890728476821192,
#    0.9130794701986755,
#    0.9333609271523179,
#    0.9391556291390728,
#    0.9528145695364238,
#    0.9428807947019867,
#    0.9627483443708609,
#    0.9515728476821192,
#    0.9668874172185431],
#   'val_loss': [0.898249573892373,
#    0.6181101993315126,
#    0.516555046378196,
#    0.3793967856847225,
#    0.4913214838477616,
#    0.40379693380650417,
#    0.3308114377402426,
#    0.34402460759430614,
#    0.3150622268805548,
#    0.3069483506808901,
#    0.3345069310704043,
#    0.368552361139787,
#    0.31346670347240685,
#    0.33507881294879327],
#   'val_accuracy': [0.7066869300911854,
#    0.8009118541033434,
#    0.8328267477203647,
#    0.8829787234042553,
#    0.8662613981762918,
#    0.9027355623100304,
#    0.9103343465045592,
#    0.9088145896656535,
#    0.9164133738601824,
#    0.9300911854103343,
#    0.9285714285714286,
#    0.9209726443768997,
#    0.9346504559270516,
#    0.9331306990881459]},
#  0.0005: {'train_loss': [1.626175797538252,
#    0.7378564946698827,
#    0.5518375386465464,
#    0.472381091275752,
#    0.36779000249919513,
#    0.3342891169699612,
#    0.29106479409514674,
#    0.28717960834207124,
#    0.25237770043066793,
#    0.21255771129928677,
#    0.18867043492119043,
#    0.18925899812421262,
#    0.18392125568938572,
#    0.16209180184350108],
#   'train_accuracy': [0.46647350993377484,
#    0.7491721854304636,
#    0.8178807947019867,
#    0.8456125827814569,
#    0.8729304635761589,
#    0.8882450331125827,
#    0.902317880794702,
#    0.9085264900662252,
#    0.9147350993377483,
#    0.9337748344370861,
#    0.9333609271523179,
#    0.9428807947019867,
#    0.9441225165562914,
#    0.9457781456953642],
#   'val_loss': [0.8770162721354186,
#    0.588372461701599,
#    0.6224460574631271,
#    0.4193243557830712,
#    0.4005072182638848,
#    0.3689080581640808,
#    0.36902892314701546,
#    0.38900299378710385,
#    0.386087279233331,
#    0.3520976159014629,
#    0.34704410336029895,
#    0.34265152166605417,
#    0.3224134887837797,
#    0.3379140217329579],
#   'val_accuracy': [0.7249240121580547,
#    0.8039513677811551,
#    0.8145896656534954,
#    0.8753799392097265,
#    0.8844984802431611,
#    0.8996960486322189,
#    0.9042553191489362,
#    0.8936170212765957,
#    0.9027355623100304,
#    0.9042553191489362,
#    0.9027355623100304,
#    0.9042553191489362,
#    0.925531914893617,
#    0.9194528875379939]}}

# %%
for lamb, ls in res.items():
    best_accuracy = ls['val_accuracy'][-1]
    print(lamb, best_accuracy)
# Out:
# 0 0.9194528875379939
# 0.01 0.8768996960486323
# 0.001 0.9346504559270516
# 0.005 0.8860182370820668
# 0.0001 0.9331306990881459
# 0.0005 0.9194528875379939

# %%
# CNN-Turbo

res_turbo = {}

for lamb in lambs:
    filename = "CNN-Turbo_lambda-"+str(lamb)+".pth"
    model, histmap = cnn_trainer(CNN_Turbo, 14, lamb)
    res_turbo[lamb] = histmap

    torch.save(model.state_dict(), filename)
    print("Saved:", filename)
# Out:
# cuda
# lambda: 0 and epoch: 1 of 14, train accuracy: 0.21812913907284767 and val accuracy: 0.29027355623100304
# lambda: 0 and epoch: 2 of 14, train accuracy: 0.29759933774834435 and val accuracy: 0.4635258358662614
# lambda: 0 and epoch: 3 of 14, train accuracy: 0.37251655629139074 and val accuracy: 0.46656534954407297
# lambda: 0 and epoch: 4 of 14, train accuracy: 0.3961092715231788 and val accuracy: 0.45288753799392095
# lambda: 0 and epoch: 5 of 14, train accuracy: 0.4019039735099338 and val accuracy: 0.49848024316109424
# lambda: 0 and epoch: 6 of 14, train accuracy: 0.43543046357615894 and val accuracy: 0.5516717325227963
# lambda: 0 and epoch: 7 of 14, train accuracy: 0.4586092715231788 and val accuracy: 0.5577507598784195
# lambda: 0 and epoch: 8 of 14, train accuracy: 0.5235927152317881 and val accuracy: 0.6975683890577508
# lambda: 0 and epoch: 9 of 14, train accuracy: 0.5778145695364238 and val accuracy: 0.723404255319149
# lambda: 0 and epoch: 10 of 14, train accuracy: 0.5844370860927153 and val accuracy: 0.7127659574468085
# lambda: 0 and epoch: 11 of 14, train accuracy: 0.605546357615894 and val accuracy: 0.729483282674772
# lambda: 0 and epoch: 12 of 14, train accuracy: 0.6080298013245033 and val accuracy: 0.7249240121580547
# lambda: 0 and epoch: 13 of 14, train accuracy: 0.6233443708609272 and val accuracy: 0.7325227963525835
# lambda: 0 and epoch: 14 of 14, train accuracy: 0.6278973509933775 and val accuracy: 0.7462006079027356
# Saved: CNN-Turbo_lambda-0.pth
# cuda
# lambda: 0.01 and epoch: 1 of 14, train accuracy: 0.3567880794701987 and val accuracy: 0.5866261398176292
# lambda: 0.01 and epoch: 2 of 14, train accuracy: 0.5724337748344371 and val accuracy: 0.6884498480243161
# lambda: 0.01 and epoch: 3 of 14, train accuracy: 0.6237582781456954 and val accuracy: 0.6930091185410334
# lambda: 0.01 and epoch: 4 of 14, train accuracy: 0.632864238410596 and val accuracy: 0.743161094224924
# lambda: 0.01 and epoch: 5 of 14, train accuracy: 0.6519039735099338 and val accuracy: 0.7598784194528876
# lambda: 0.01 and epoch: 6 of 14, train accuracy: 0.6808774834437086 and val accuracy: 0.7613981762917933
# lambda: 0.01 and epoch: 7 of 14, train accuracy: 0.6825331125827815 and val accuracy: 0.6276595744680851
# lambda: 0.01 and epoch: 8 of 14, train accuracy: 0.6854304635761589 and val accuracy: 0.7613981762917933
# lambda: 0.01 and epoch: 9 of 14, train accuracy: 0.6875 and val accuracy: 0.7522796352583586
# lambda: 0.01 and epoch: 10 of 14, train accuracy: 0.6932947019867549 and val accuracy: 0.7887537993920972
# lambda: 0.01 and epoch: 11 of 14, train accuracy: 0.7293046357615894 and val accuracy: 0.7933130699088146
# lambda: 0.01 and epoch: 12 of 14, train accuracy: 0.7119205298013245 and val accuracy: 0.7781155015197568
# lambda: 0.01 and epoch: 13 of 14, train accuracy: 0.7127483443708609 and val accuracy: 0.7522796352583586
# lambda: 0.01 and epoch: 14 of 14, train accuracy: 0.7189569536423841 and val accuracy: 0.7933130699088146
# Saved: CNN-Turbo_lambda-0.01.pth
# cuda
# lambda: 0.001 and epoch: 1 of 14, train accuracy: 0.16763245033112584 and val accuracy: 0.27203647416413373
# lambda: 0.001 and epoch: 2 of 14, train accuracy: 0.3253311258278146 and val accuracy: 0.4072948328267477
# lambda: 0.001 and epoch: 3 of 14, train accuracy: 0.37706953642384106 and val accuracy: 0.43617021276595747
# lambda: 0.001 and epoch: 4 of 14, train accuracy: 0.3853476821192053 and val accuracy: 0.45288753799392095
# lambda: 0.001 and epoch: 5 of 14, train accuracy: 0.4060430463576159 and val accuracy: 0.4696048632218845
# lambda: 0.001 and epoch: 6 of 14, train accuracy: 0.4064569536423841 and val accuracy: 0.4939209726443769
# lambda: 0.001 and epoch: 7 of 14, train accuracy: 0.4954470198675497 and val accuracy: 0.6534954407294833
# lambda: 0.001 and epoch: 8 of 14, train accuracy: 0.515728476821192 and val accuracy: 0.648936170212766
# lambda: 0.001 and epoch: 9 of 14, train accuracy: 0.5471854304635762 and val accuracy: 0.60790273556231
# lambda: 0.001 and epoch: 10 of 14, train accuracy: 0.5558774834437086 and val accuracy: 0.6291793313069909
# lambda: 0.001 and epoch: 11 of 14, train accuracy: 0.581953642384106 and val accuracy: 0.7279635258358662
# lambda: 0.001 and epoch: 12 of 14, train accuracy: 0.5720198675496688 and val accuracy: 0.7264437689969605
# lambda: 0.001 and epoch: 13 of 14, train accuracy: 0.605546357615894 and val accuracy: 0.7279635258358662
# lambda: 0.001 and epoch: 14 of 14, train accuracy: 0.6200331125827815 and val accuracy: 0.7188449848024316
# Saved: CNN-Turbo_lambda-0.001.pth
# cuda
# lambda: 0.005 and epoch: 1 of 14, train accuracy: 0.29346026490066224 and val accuracy: 0.5866261398176292
# lambda: 0.005 and epoch: 2 of 14, train accuracy: 0.5426324503311258 and val accuracy: 0.6428571428571429
# lambda: 0.005 and epoch: 3 of 14, train accuracy: 0.6051324503311258 and val accuracy: 0.6990881458966566
# lambda: 0.005 and epoch: 4 of 14, train accuracy: 0.6312086092715232 and val accuracy: 0.6474164133738601
# lambda: 0.005 and epoch: 5 of 14, train accuracy: 0.6622516556291391 and val accuracy: 0.7674772036474165
# lambda: 0.005 and epoch: 6 of 14, train accuracy: 0.6788079470198676 and val accuracy: 0.776595744680851
# lambda: 0.005 and epoch: 7 of 14, train accuracy: 0.7152317880794702 and val accuracy: 0.7933130699088146
# lambda: 0.005 and epoch: 8 of 14, train accuracy: 0.6995033112582781 and val accuracy: 0.7948328267477204
# lambda: 0.005 and epoch: 9 of 14, train accuracy: 0.7102649006622517 and val accuracy: 0.770516717325228
# lambda: 0.005 and epoch: 10 of 14, train accuracy: 0.706953642384106 and val accuracy: 0.7978723404255319
# lambda: 0.005 and epoch: 11 of 14, train accuracy: 0.7326158940397351 and val accuracy: 0.8009118541033434
# lambda: 0.005 and epoch: 12 of 14, train accuracy: 0.7173013245033113 and val accuracy: 0.7978723404255319
# lambda: 0.005 and epoch: 13 of 14, train accuracy: 0.7346854304635762 and val accuracy: 0.7978723404255319
# lambda: 0.005 and epoch: 14 of 14, train accuracy: 0.7334437086092715 and val accuracy: 0.7355623100303952
# Saved: CNN-Turbo_lambda-0.005.pth
# cuda
# lambda: 0.0001 and epoch: 1 of 14, train accuracy: 0.18418874172185432 and val accuracy: 0.2613981762917933
# lambda: 0.0001 and epoch: 2 of 14, train accuracy: 0.2367549668874172 and val accuracy: 0.24924012158054712
# lambda: 0.0001 and epoch: 3 of 14, train accuracy: 0.2706953642384106 and val accuracy: 0.3541033434650456
# lambda: 0.0001 and epoch: 4 of 14, train accuracy: 0.320364238410596 and val accuracy: 0.3981762917933131
# lambda: 0.0001 and epoch: 5 of 14, train accuracy: 0.3485099337748344 and val accuracy: 0.3768996960486322
# lambda: 0.0001 and epoch: 6 of 14, train accuracy: 0.3617549668874172 and val accuracy: 0.45288753799392095
# lambda: 0.0001 and epoch: 7 of 14, train accuracy: 0.38079470198675497 and val accuracy: 0.4726443768996961
# lambda: 0.0001 and epoch: 8 of 14, train accuracy: 0.3882450331125828 and val accuracy: 0.46200607902735563
# lambda: 0.0001 and epoch: 9 of 14, train accuracy: 0.4288079470198676 and val accuracy: 0.46200607902735563
# lambda: 0.0001 and epoch: 10 of 14, train accuracy: 0.4192880794701987 and val accuracy: 0.5197568389057751
# lambda: 0.0001 and epoch: 11 of 14, train accuracy: 0.4470198675496689 and val accuracy: 0.5592705167173252
# lambda: 0.0001 and epoch: 12 of 14, train accuracy: 0.49337748344370863 and val accuracy: 0.621580547112462
# lambda: 0.0001 and epoch: 13 of 14, train accuracy: 0.5186258278145696 and val accuracy: 0.6428571428571429
# lambda: 0.0001 and epoch: 14 of 14, train accuracy: 0.5475993377483444 and val accuracy: 0.6717325227963525
# Saved: CNN-Turbo_lambda-0.0001.pth
# cuda
# lambda: 0.0005 and epoch: 1 of 14, train accuracy: 0.20322847682119205 and val accuracy: 0.3601823708206687
# lambda: 0.0005 and epoch: 2 of 14, train accuracy: 0.3472682119205298 and val accuracy: 0.41033434650455924
# lambda: 0.0005 and epoch: 3 of 14, train accuracy: 0.4163907284768212 and val accuracy: 0.46808510638297873
# lambda: 0.0005 and epoch: 4 of 14, train accuracy: 0.4093543046357616 and val accuracy: 0.44832826747720367
# lambda: 0.0005 and epoch: 5 of 14, train accuracy: 0.45240066225165565 and val accuracy: 0.5668693009118541
# lambda: 0.0005 and epoch: 6 of 14, train accuracy: 0.4855132450331126 and val accuracy: 0.60790273556231
# lambda: 0.0005 and epoch: 7 of 14, train accuracy: 0.5086920529801324 and val accuracy: 0.6899696048632219
# lambda: 0.0005 and epoch: 8 of 14, train accuracy: 0.5558774834437086 and val accuracy: 0.6793313069908815
# lambda: 0.0005 and epoch: 9 of 14, train accuracy: 0.5980960264900662 and val accuracy: 0.709726443768997
# lambda: 0.0005 and epoch: 10 of 14, train accuracy: 0.6129966887417219 and val accuracy: 0.7066869300911854
# lambda: 0.0005 and epoch: 11 of 14, train accuracy: 0.6262417218543046 and val accuracy: 0.743161094224924
# lambda: 0.0005 and epoch: 12 of 14, train accuracy: 0.6481788079470199 and val accuracy: 0.7522796352583586
# lambda: 0.0005 and epoch: 13 of 14, train accuracy: 0.6817052980132451 and val accuracy: 0.7978723404255319
# lambda: 0.0005 and epoch: 14 of 14, train accuracy: 0.7024006622516556 and val accuracy: 0.8191489361702128
# Saved: CNN-Turbo_lambda-0.0005.pth

# %%
for lamb, ls in res_turbo.items():
    best_accuracy = ls['val_accuracy'][-1]
    print(lamb, best_accuracy)
# Out:
# 0 0.7462006079027356
# 0.01 0.7933130699088146
# 0.001 0.7188449848024316
# 0.005 0.7355623100303952
# 0.0001 0.6717325227963525
# 0.0005 0.8191489361702128

# %%
res_ultra = {}

for lamb in lambs:
    filename = "CNN-Ultra_lambda-"+str(lamb)+".pth"
    model, histmap = cnn_trainer(CNN_Ultra, 14, lamb)
    res_ultra[lamb] = histmap

    torch.save(model.state_dict(), filename)
    print("Saved:", filename)
# Out:
# cuda
# lambda: 0 and epoch: 1 of 14, train accuracy: 0.4586092715231788 and val accuracy: 0.6930091185410334
# lambda: 0 and epoch: 2 of 14, train accuracy: 0.7392384105960265 and val accuracy: 0.817629179331307
# lambda: 0 and epoch: 3 of 14, train accuracy: 0.8182947019867549 and val accuracy: 0.8358662613981763
# lambda: 0 and epoch: 4 of 14, train accuracy: 0.8551324503311258 and val accuracy: 0.8677811550151976
# lambda: 0 and epoch: 5 of 14, train accuracy: 0.8754139072847682 and val accuracy: 0.8753799392097265
# lambda: 0 and epoch: 6 of 14, train accuracy: 0.8965231788079471 and val accuracy: 0.89209726443769
# lambda: 0 and epoch: 7 of 14, train accuracy: 0.9048013245033113 and val accuracy: 0.9027355623100304
# lambda: 0 and epoch: 8 of 14, train accuracy: 0.9325331125827815 and val accuracy: 0.8996960486322189
# lambda: 0 and epoch: 9 of 14, train accuracy: 0.9466059602649006 and val accuracy: 0.9376899696048632
# lambda: 0 and epoch: 10 of 14, train accuracy: 0.9461920529801324 and val accuracy: 0.9042553191489362
# lambda: 0 and epoch: 11 of 14, train accuracy: 0.9573675496688742 and val accuracy: 0.9285714285714286
# lambda: 0 and epoch: 12 of 14, train accuracy: 0.953228476821192 and val accuracy: 0.9224924012158054
# lambda: 0 and epoch: 13 of 14, train accuracy: 0.956953642384106 and val accuracy: 0.9316109422492401
# lambda: 0 and epoch: 14 of 14, train accuracy: 0.9710264900662252 and val accuracy: 0.9346504559270516
# Saved: CNN-Ultra_lambda-0.pth
# cuda
# lambda: 0.01 and epoch: 1 of 14, train accuracy: 0.3820364238410596 and val accuracy: 0.6610942249240122
# lambda: 0.01 and epoch: 2 of 14, train accuracy: 0.6477649006622517 and val accuracy: 0.6945288753799392
# lambda: 0.01 and epoch: 3 of 14, train accuracy: 0.742135761589404 and val accuracy: 0.8100303951367781
# lambda: 0.01 and epoch: 4 of 14, train accuracy: 0.7628311258278145 and val accuracy: 0.8237082066869301
# lambda: 0.01 and epoch: 5 of 14, train accuracy: 0.7901490066225165 and val accuracy: 0.8328267477203647
# lambda: 0.01 and epoch: 6 of 14, train accuracy: 0.7959437086092715 and val accuracy: 0.7978723404255319
# lambda: 0.01 and epoch: 7 of 14, train accuracy: 0.8120860927152318 and val accuracy: 0.7750759878419453
# lambda: 0.01 and epoch: 8 of 14, train accuracy: 0.8236754966887417 and val accuracy: 0.8449848024316109
# lambda: 0.01 and epoch: 9 of 14, train accuracy: 0.8373344370860927 and val accuracy: 0.8237082066869301
# lambda: 0.01 and epoch: 10 of 14, train accuracy: 0.8418874172185431 and val accuracy: 0.8586626139817629
# lambda: 0.01 and epoch: 11 of 14, train accuracy: 0.8580298013245033 and val accuracy: 0.8693009118541033
# lambda: 0.01 and epoch: 12 of 14, train accuracy: 0.8625827814569537 and val accuracy: 0.8465045592705167
# lambda: 0.01 and epoch: 13 of 14, train accuracy: 0.8410596026490066 and val accuracy: 0.8829787234042553
# lambda: 0.01 and epoch: 14 of 14, train accuracy: 0.8629966887417219 and val accuracy: 0.851063829787234
# Saved: CNN-Ultra_lambda-0.01.pth
# cuda
# lambda: 0.001 and epoch: 1 of 14, train accuracy: 0.3679635761589404 and val accuracy: 0.6702127659574468
# lambda: 0.001 and epoch: 2 of 14, train accuracy: 0.6912251655629139 and val accuracy: 0.7477203647416414
# lambda: 0.001 and epoch: 3 of 14, train accuracy: 0.7495860927152318 and val accuracy: 0.8024316109422492
# lambda: 0.001 and epoch: 4 of 14, train accuracy: 0.8195364238410596 and val accuracy: 0.831306990881459
# lambda: 0.001 and epoch: 5 of 14, train accuracy: 0.8352649006622517 and val accuracy: 0.8389057750759878
# lambda: 0.001 and epoch: 6 of 14, train accuracy: 0.8621688741721855 and val accuracy: 0.8601823708206687
# lambda: 0.001 and epoch: 7 of 14, train accuracy: 0.8716887417218543 and val accuracy: 0.8738601823708206
# lambda: 0.001 and epoch: 8 of 14, train accuracy: 0.8799668874172185 and val accuracy: 0.8966565349544073
# lambda: 0.001 and epoch: 9 of 14, train accuracy: 0.8952814569536424 and val accuracy: 0.8996960486322189
# lambda: 0.001 and epoch: 10 of 14, train accuracy: 0.8927980132450332 and val accuracy: 0.9012158054711246
# lambda: 0.001 and epoch: 11 of 14, train accuracy: 0.9172185430463576 and val accuracy: 0.9057750759878419
# lambda: 0.001 and epoch: 12 of 14, train accuracy: 0.9155629139072847 and val accuracy: 0.9179331306990881
# lambda: 0.001 and epoch: 13 of 14, train accuracy: 0.929635761589404 and val accuracy: 0.9072948328267477
# lambda: 0.001 and epoch: 14 of 14, train accuracy: 0.9225993377483444 and val accuracy: 0.8936170212765957
# Saved: CNN-Ultra_lambda-0.001.pth
# cuda
# lambda: 0.005 and epoch: 1 of 14, train accuracy: 0.4548841059602649 and val accuracy: 0.6367781155015197
# lambda: 0.005 and epoch: 2 of 14, train accuracy: 0.6895695364238411 and val accuracy: 0.6960486322188449
# lambda: 0.005 and epoch: 3 of 14, train accuracy: 0.7288907284768212 and val accuracy: 0.7446808510638298
# lambda: 0.005 and epoch: 4 of 14, train accuracy: 0.7628311258278145 and val accuracy: 0.7993920972644377
# lambda: 0.005 and epoch: 5 of 14, train accuracy: 0.7826986754966887 and val accuracy: 0.8221884498480243
# lambda: 0.005 and epoch: 6 of 14, train accuracy: 0.8067052980132451 and val accuracy: 0.831306990881459
# lambda: 0.005 and epoch: 7 of 14, train accuracy: 0.8182947019867549 and val accuracy: 0.8586626139817629
# lambda: 0.005 and epoch: 8 of 14, train accuracy: 0.8427152317880795 and val accuracy: 0.8465045592705167
# lambda: 0.005 and epoch: 9 of 14, train accuracy: 0.855546357615894 and val accuracy: 0.8632218844984803
# lambda: 0.005 and epoch: 10 of 14, train accuracy: 0.8663079470198676 and val accuracy: 0.8571428571428571
# lambda: 0.005 and epoch: 11 of 14, train accuracy: 0.8721026490066225 and val accuracy: 0.8601823708206687
# lambda: 0.005 and epoch: 12 of 14, train accuracy: 0.8551324503311258 and val accuracy: 0.878419452887538
# lambda: 0.005 and epoch: 13 of 14, train accuracy: 0.8836920529801324 and val accuracy: 0.8647416413373861
# lambda: 0.005 and epoch: 14 of 14, train accuracy: 0.882864238410596 and val accuracy: 0.8844984802431611
# Saved: CNN-Ultra_lambda-0.005.pth
# cuda
# lambda: 0.0001 and epoch: 1 of 14, train accuracy: 0.46978476821192056 and val accuracy: 0.6124620060790273
# lambda: 0.0001 and epoch: 2 of 14, train accuracy: 0.7131622516556292 and val accuracy: 0.6534954407294833
# lambda: 0.0001 and epoch: 3 of 14, train accuracy: 0.8004966887417219 and val accuracy: 0.8419452887537994
# lambda: 0.0001 and epoch: 4 of 14, train accuracy: 0.8423013245033113 and val accuracy: 0.8693009118541033
# lambda: 0.0001 and epoch: 5 of 14, train accuracy: 0.8766556291390728 and val accuracy: 0.8936170212765957
# lambda: 0.0001 and epoch: 6 of 14, train accuracy: 0.9002483443708609 and val accuracy: 0.8662613981762918
# lambda: 0.0001 and epoch: 7 of 14, train accuracy: 0.9110099337748344 and val accuracy: 0.898176291793313
# lambda: 0.0001 and epoch: 8 of 14, train accuracy: 0.9184602649006622 and val accuracy: 0.9118541033434651
# lambda: 0.0001 and epoch: 9 of 14, train accuracy: 0.9408112582781457 and val accuracy: 0.9057750759878419
# lambda: 0.0001 and epoch: 10 of 14, train accuracy: 0.9424668874172185 and val accuracy: 0.9240121580547113
# lambda: 0.0001 and epoch: 11 of 14, train accuracy: 0.9548841059602649 and val accuracy: 0.9027355623100304
# lambda: 0.0001 and epoch: 12 of 14, train accuracy: 0.9573675496688742 and val accuracy: 0.9194528875379939
# lambda: 0.0001 and epoch: 13 of 14, train accuracy: 0.9635761589403974 and val accuracy: 0.9194528875379939
# lambda: 0.0001 and epoch: 14 of 14, train accuracy: 0.9652317880794702 and val accuracy: 0.9133738601823708
# Saved: CNN-Ultra_lambda-0.0001.pth
# cuda
# lambda: 0.0005 and epoch: 1 of 14, train accuracy: 0.37334437086092714 and val accuracy: 0.6398176291793313
# lambda: 0.0005 and epoch: 2 of 14, train accuracy: 0.6659768211920529 and val accuracy: 0.7477203647416414
# lambda: 0.0005 and epoch: 3 of 14, train accuracy: 0.7603476821192053 and val accuracy: 0.7948328267477204
# lambda: 0.0005 and epoch: 4 of 14, train accuracy: 0.8079470198675497 and val accuracy: 0.8662613981762918
# lambda: 0.0005 and epoch: 5 of 14, train accuracy: 0.8274006622516556 and val accuracy: 0.8404255319148937
# lambda: 0.0005 and epoch: 6 of 14, train accuracy: 0.8456125827814569 and val accuracy: 0.8677811550151976
# lambda: 0.0005 and epoch: 7 of 14, train accuracy: 0.8704470198675497 and val accuracy: 0.8601823708206687
# lambda: 0.0005 and epoch: 8 of 14, train accuracy: 0.8803807947019867 and val accuracy: 0.9118541033434651
# lambda: 0.0005 and epoch: 9 of 14, train accuracy: 0.8919701986754967 and val accuracy: 0.898176291793313
# lambda: 0.0005 and epoch: 10 of 14, train accuracy: 0.9114238410596026 and val accuracy: 0.9164133738601824
# lambda: 0.0005 and epoch: 11 of 14, train accuracy: 0.902317880794702 and val accuracy: 0.9012158054711246
# lambda: 0.0005 and epoch: 12 of 14, train accuracy: 0.9238410596026491 and val accuracy: 0.9012158054711246
# lambda: 0.0005 and epoch: 13 of 14, train accuracy: 0.9346026490066225 and val accuracy: 0.8905775075987842
# lambda: 0.0005 and epoch: 14 of 14, train accuracy: 0.9288079470198676 and val accuracy: 0.8996960486322189
# Saved: CNN-Ultra_lambda-0.0005.pth

# %%
for lamb, ls in res_ultra.items():
    best_accuracy = ls['val_accuracy'][-1]
    print(lamb, best_accuracy)
# Out:
# 0 0.9346504559270516
# 0.01 0.851063829787234
# 0.001 0.8936170212765957
# 0.005 0.8844984802431611
# 0.0001 0.9133738601823708
# 0.0005 0.8996960486322189

# %%
res_lite = {}

for lamb in lambs:
    filename = "CNN-Lite_lambda-"+str(lamb)+".pth"
    model, histmap = cnn_trainer(CNN_Lite, 14, lamb)
    res_lite[lamb] = histmap

    torch.save(model.state_dict(), filename)
    print("Saved:", filename)
# Out:
# cuda
# lambda: 0 and epoch: 1 of 14, train accuracy: 0.5107615894039735 and val accuracy: 0.7477203647416414
# lambda: 0 and epoch: 2 of 14, train accuracy: 0.7632450331125827 and val accuracy: 0.8191489361702128
# lambda: 0 and epoch: 3 of 14, train accuracy: 0.828228476821192 and val accuracy: 0.8541033434650456
# lambda: 0 and epoch: 4 of 14, train accuracy: 0.8551324503311258 and val accuracy: 0.8677811550151976
# lambda: 0 and epoch: 5 of 14, train accuracy: 0.8882450331125827 and val accuracy: 0.8662613981762918
# lambda: 0 and epoch: 6 of 14, train accuracy: 0.8932119205298014 and val accuracy: 0.8875379939209727
# lambda: 0 and epoch: 7 of 14, train accuracy: 0.9242549668874173 and val accuracy: 0.8844984802431611
# lambda: 0 and epoch: 8 of 14, train accuracy: 0.9337748344370861 and val accuracy: 0.8996960486322189
# lambda: 0 and epoch: 9 of 14, train accuracy: 0.9432947019867549 and val accuracy: 0.8905775075987842
# lambda: 0 and epoch: 10 of 14, train accuracy: 0.9540562913907285 and val accuracy: 0.8966565349544073
# lambda: 0 and epoch: 11 of 14, train accuracy: 0.9598509933774835 and val accuracy: 0.9042553191489362
# lambda: 0 and epoch: 12 of 14, train accuracy: 0.9619205298013245 and val accuracy: 0.9042553191489362
# lambda: 0 and epoch: 13 of 14, train accuracy: 0.9673013245033113 and val accuracy: 0.9133738601823708
# lambda: 0 and epoch: 14 of 14, train accuracy: 0.9751655629139073 and val accuracy: 0.9118541033434651
# Saved: CNN-Lite_lambda-0.pth
# cuda
# lambda: 0.01 and epoch: 1 of 14, train accuracy: 0.5285596026490066 and val accuracy: 0.7887537993920972
# lambda: 0.01 and epoch: 2 of 14, train accuracy: 0.7562086092715232 and val accuracy: 0.8115501519756839
# lambda: 0.01 and epoch: 3 of 14, train accuracy: 0.8054635761589404 and val accuracy: 0.8632218844984803
# lambda: 0.01 and epoch: 4 of 14, train accuracy: 0.8199503311258278 and val accuracy: 0.8525835866261399
# lambda: 0.01 and epoch: 5 of 14, train accuracy: 0.8385761589403974 and val accuracy: 0.8054711246200608
# lambda: 0.01 and epoch: 6 of 14, train accuracy: 0.8360927152317881 and val accuracy: 0.8358662613981763
# lambda: 0.01 and epoch: 7 of 14, train accuracy: 0.8534768211920529 and val accuracy: 0.8647416413373861
# lambda: 0.01 and epoch: 8 of 14, train accuracy: 0.8621688741721855 and val accuracy: 0.8738601823708206
# lambda: 0.01 and epoch: 9 of 14, train accuracy: 0.8683774834437086 and val accuracy: 0.8662613981762918
# lambda: 0.01 and epoch: 10 of 14, train accuracy: 0.8733443708609272 and val accuracy: 0.8647416413373861
# lambda: 0.01 and epoch: 11 of 14, train accuracy: 0.8712748344370861 and val accuracy: 0.8404255319148937
# lambda: 0.01 and epoch: 12 of 14, train accuracy: 0.8795529801324503 and val accuracy: 0.8814589665653495
# lambda: 0.01 and epoch: 13 of 14, train accuracy: 0.8791390728476821 and val accuracy: 0.8677811550151976
# lambda: 0.01 and epoch: 14 of 14, train accuracy: 0.8878311258278145 and val accuracy: 0.8875379939209727
# Saved: CNN-Lite_lambda-0.01.pth
# cuda
# lambda: 0.001 and epoch: 1 of 14, train accuracy: 0.5840231788079471 and val accuracy: 0.790273556231003
# lambda: 0.001 and epoch: 2 of 14, train accuracy: 0.8079470198675497 and val accuracy: 0.8495440729483282
# lambda: 0.001 and epoch: 3 of 14, train accuracy: 0.8617549668874173 and val accuracy: 0.8647416413373861
# lambda: 0.001 and epoch: 4 of 14, train accuracy: 0.8923841059602649 and val accuracy: 0.8723404255319149
# lambda: 0.001 and epoch: 5 of 14, train accuracy: 0.9147350993377483 and val accuracy: 0.8753799392097265
# lambda: 0.001 and epoch: 6 of 14, train accuracy: 0.921771523178808 and val accuracy: 0.8936170212765957
# lambda: 0.001 and epoch: 7 of 14, train accuracy: 0.9337748344370861 and val accuracy: 0.878419452887538
# lambda: 0.001 and epoch: 8 of 14, train accuracy: 0.9445364238410596 and val accuracy: 0.9012158054711246
# lambda: 0.001 and epoch: 9 of 14, train accuracy: 0.9379139072847682 and val accuracy: 0.8951367781155015
# lambda: 0.001 and epoch: 10 of 14, train accuracy: 0.9445364238410596 and val accuracy: 0.9088145896656535
# lambda: 0.001 and epoch: 11 of 14, train accuracy: 0.9548841059602649 and val accuracy: 0.9057750759878419
# lambda: 0.001 and epoch: 12 of 14, train accuracy: 0.9540562913907285 and val accuracy: 0.878419452887538
# lambda: 0.001 and epoch: 13 of 14, train accuracy: 0.9540562913907285 and val accuracy: 0.9133738601823708
# lambda: 0.001 and epoch: 14 of 14, train accuracy: 0.9635761589403974 and val accuracy: 0.8951367781155015
# Saved: CNN-Lite_lambda-0.001.pth
# cuda
# lambda: 0.005 and epoch: 1 of 14, train accuracy: 0.5475993377483444 and val accuracy: 0.776595744680851
# lambda: 0.005 and epoch: 2 of 14, train accuracy: 0.7512417218543046 and val accuracy: 0.8419452887537994
# lambda: 0.005 and epoch: 3 of 14, train accuracy: 0.8108443708609272 and val accuracy: 0.851063829787234
# lambda: 0.005 and epoch: 4 of 14, train accuracy: 0.8302980132450332 and val accuracy: 0.8449848024316109
# lambda: 0.005 and epoch: 5 of 14, train accuracy: 0.8431291390728477 and val accuracy: 0.8465045592705167
# lambda: 0.005 and epoch: 6 of 14, train accuracy: 0.8518211920529801 and val accuracy: 0.8541033434650456
# lambda: 0.005 and epoch: 7 of 14, train accuracy: 0.859271523178808 and val accuracy: 0.8571428571428571
# lambda: 0.005 and epoch: 8 of 14, train accuracy: 0.8799668874172185 and val accuracy: 0.8647416413373861
# lambda: 0.005 and epoch: 9 of 14, train accuracy: 0.8903145695364238 and val accuracy: 0.8708206686930091
# lambda: 0.005 and epoch: 10 of 14, train accuracy: 0.8853476821192053 and val accuracy: 0.8936170212765957
# lambda: 0.005 and epoch: 11 of 14, train accuracy: 0.8948675496688742 and val accuracy: 0.8814589665653495
# lambda: 0.005 and epoch: 12 of 14, train accuracy: 0.8915562913907285 and val accuracy: 0.8647416413373861
# lambda: 0.005 and epoch: 13 of 14, train accuracy: 0.8973509933774835 and val accuracy: 0.9012158054711246
# lambda: 0.005 and epoch: 14 of 14, train accuracy: 0.9130794701986755 and val accuracy: 0.8844984802431611
# Saved: CNN-Lite_lambda-0.005.pth
# cuda
# lambda: 0.0001 and epoch: 1 of 14, train accuracy: 0.5902317880794702 and val accuracy: 0.7857142857142857
# lambda: 0.0001 and epoch: 2 of 14, train accuracy: 0.785182119205298 and val accuracy: 0.8161094224924013
# lambda: 0.0001 and epoch: 3 of 14, train accuracy: 0.8493377483443708 and val accuracy: 0.8723404255319149
# lambda: 0.0001 and epoch: 4 of 14, train accuracy: 0.8915562913907285 and val accuracy: 0.8465045592705167
# lambda: 0.0001 and epoch: 5 of 14, train accuracy: 0.9089403973509934 and val accuracy: 0.9012158054711246
# lambda: 0.0001 and epoch: 6 of 14, train accuracy: 0.9457781456953642 and val accuracy: 0.9042553191489362
# lambda: 0.0001 and epoch: 7 of 14, train accuracy: 0.9474337748344371 and val accuracy: 0.9133738601823708
# lambda: 0.0001 and epoch: 8 of 14, train accuracy: 0.9615066225165563 and val accuracy: 0.9179331306990881
# lambda: 0.0001 and epoch: 9 of 14, train accuracy: 0.9561258278145696 and val accuracy: 0.8951367781155015
# lambda: 0.0001 and epoch: 10 of 14, train accuracy: 0.9615066225165563 and val accuracy: 0.9027355623100304
# lambda: 0.0001 and epoch: 11 of 14, train accuracy: 0.9751655629139073 and val accuracy: 0.9285714285714286
# lambda: 0.0001 and epoch: 12 of 14, train accuracy: 0.9834437086092715 and val accuracy: 0.9224924012158054
# lambda: 0.0001 and epoch: 13 of 14, train accuracy: 0.9888245033112583 and val accuracy: 0.9240121580547113
# lambda: 0.0001 and epoch: 14 of 14, train accuracy: 0.9809602649006622 and val accuracy: 0.9300911854103343
# Saved: CNN-Lite_lambda-0.0001.pth
# cuda
# lambda: 0.0005 and epoch: 1 of 14, train accuracy: 0.5513245033112583 and val accuracy: 0.7279635258358662
# lambda: 0.0005 and epoch: 2 of 14, train accuracy: 0.7810430463576159 and val accuracy: 0.8297872340425532
# lambda: 0.0005 and epoch: 3 of 14, train accuracy: 0.8460264900662252 and val accuracy: 0.8282674772036475
# lambda: 0.0005 and epoch: 4 of 14, train accuracy: 0.8737582781456954 and val accuracy: 0.8753799392097265
# lambda: 0.0005 and epoch: 5 of 14, train accuracy: 0.8973509933774835 and val accuracy: 0.8799392097264438
# lambda: 0.0005 and epoch: 6 of 14, train accuracy: 0.9213576158940397 and val accuracy: 0.8966565349544073
# lambda: 0.0005 and epoch: 7 of 14, train accuracy: 0.9279801324503312 and val accuracy: 0.8951367781155015
# lambda: 0.0005 and epoch: 8 of 14, train accuracy: 0.9362582781456954 and val accuracy: 0.8936170212765957
# lambda: 0.0005 and epoch: 9 of 14, train accuracy: 0.9507450331125827 and val accuracy: 0.8936170212765957
# lambda: 0.0005 and epoch: 10 of 14, train accuracy: 0.9557119205298014 and val accuracy: 0.9103343465045592
# lambda: 0.0005 and epoch: 11 of 14, train accuracy: 0.9598509933774835 and val accuracy: 0.9088145896656535
# lambda: 0.0005 and epoch: 12 of 14, train accuracy: 0.953228476821192 and val accuracy: 0.9012158054711246
# lambda: 0.0005 and epoch: 13 of 14, train accuracy: 0.9639900662251656 and val accuracy: 0.9133738601823708
# lambda: 0.0005 and epoch: 14 of 14, train accuracy: 0.9631622516556292 and val accuracy: 0.9103343465045592
# Saved: CNN-Lite_lambda-0.0005.pth

# %%
for lamb, ls in res_lite.items():
    best_accuracy = ls['val_accuracy'][-1]
    print(lamb, best_accuracy)
# Out:
# 0 0.9118541033434651
# 0.01 0.8875379939209727
# 0.001 0.8951367781155015
# 0.005 0.8844984802431611
# 0.0001 0.9300911854103343
# 0.0005 0.9103343465045592
